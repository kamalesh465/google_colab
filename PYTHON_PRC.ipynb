# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalesh465/google_colab/blob/main/PYTHON_PRC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = []
def   lst_squre(lst1):
  for i in lst1:
    lst.append(i*i)
  return lst

# %%
lst_squre([1,2,3,4,5,6,7])
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
lst = [1,2,3,4,5,6,7]

# %%
[i*i for i in lst if i%2!=0 ]
# Out:
# [1, 9, 25, 49]

# %%
## STRING FORMATTING

# %%
def greet(name):
  return "hello {}.welcome to the community".format(name)

# %%
greet("kamal")
# Out:
# 'hello kamal.welcome to the community'

# %%
## double parameter
def gff(name,age):
  return "hello {name} . your age is {age}".format(name = name,age = age)
gff("kamal",20)
# Out:
# 'hello kamal . your age is 20'

# %%
for i in lst:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
list1 = iter(lst)

# %%
next(list1)
# Out:
# 2

# %%
import
active_imports()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2289707712.py in <cell line: 0>()
# ----> 1 active_imports()
#
# NameError: name 'active_imports' is not defined

# %%
class car:
  pass

# %%
car1 = car()
car1

# %%
dir(car1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
a = int(input("enter the number :"))
# Out:
# enter the number :12
